# %% [markdown]
# # Pandas introduction

# %% [markdown]
# PANDAS
#
# 📚 Data Preprocesing in Machine Learning using Pandas
#
# 🔗 Data preprocessing is required tasks for cleaning the data and making it suitable for a machine learning model which also increases the accuracy and efficiency of a machine learning model.
#
# 🎯 Pandas is an open source Python package that is most widely used for data science/data analysis and machine learning tasks. It is built on top of another package named Numpy, which provides support for multi-dimensional arrays. Preprocessing is the process of doing a pre-analysis of data, in order to transform them into a standard and normalized format.
#
# 💡 Preprocessing involves the following aspects:
#
# missing values
# data standardization
# data normalization
# data binning

# %% [markdown]
# ## Practice codes

# %%
import pandas as pd

data = {
    "cars": ["BMW", "Volvo", "Ford"],
    "models": ["2007", "2008", "2015"],
    "passenger":["4", "6", "6"]
}
data
# Out:
# {'cars': ['BMW', 'Volvo', 'Ford'],
#  'models': ['2007', '2008', '2015'],
#  'passenger': ['4', '6', '6']}

# %%
# Apparently DataFrame() is a funciton of pandas that converts a dictionary
#  to a dataframe
df = pd.DataFrame(data)
df
# Out:
#     cars models passenger
# 0    BMW   2007         4
# 1  Volvo   2008         6
# 2   Ford   2015         6

# %%
df.to_csv("car_data.csv")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df.to_csv("/content/drive/MyDrive/Colab Notebooks/AI training/car_data.csv")

# %%
cal_data = {
    "calories":[420, 500, 300],
    "duration":[50, 60, 45]
}
cal_df = pd.DataFrame(cal_data)
cal_df
# Out:
#    calories  duration
# 0       420        50
# 1       500        60
# 2       300        45

# %%
# cal_df.to_csv("/content/drive/MyDrive/Colab Notebooks/AI training/calories_data.csv")

# %%
print(cal_df.loc[[0,1]])
# Out:
#    calories  duration
# 0       420        50
# 1       500        60

# %%
# create dataframe with indexing
import pandas as pd
data = {
    "calories":[420,300,390],
    "duration":[50,40,45]
}

df_new = pd.DataFrame(data, index = ["day1", "day2", "day3"])
df_new
# Out:
#       calories  duration
# day1       420        50
# day2       300        40
# day3       390        45

# %%
print(df_new.loc[["day1","day2","day3"]])
# Out:
#       calories  duration
# day1       420        50
# day2       300        40
# day3       390        45

# %% [markdown]
# # Data cleaning

# %%
import pandas as sandip_bhalu
df = sandip_bhalu.read_csv("/content/drive/MyDrive/Colab Notebooks/AI training/dataset.csv")
df.head(5)
# Out:
#    Duration  Date        Pulse  Maxpulse  Calories  Unnamed: 5
# 0         0    60  2020/12/01'       110       130       409.1
# 1         1    60  2020/12/02'       117       145       479.0
# 2         2    60  2020/12/03'       103       135       340.0
# 3         3    45  2020/12/04'       109       175       282.4
# 4         4    45  2020/12/05'       117       148       406.0

# %%
print(df)
# Out:
#     Duration  Date       Pulse  Maxpulse  Calories  Unnamed: 5
# 0          0    60  2020/12/01       110       130       409.1
# 1          1    60  2020/12/02       117       145       479.0
# 2          2    60  2020/12/03       103       135       340.0
# 3          3    45  2020/12/04       109       175       282.4
# 4          4    45  2020/12/05       117       148       406.0
# 5          5    60  2020/12/06       102       127       300.0
# 6          6    60  2020/12/07       110       136       374.0
# 7          7   450  2020/12/08       104       134       253.3
# 8          8    30  2020/12/09       109       133       195.1
# 9          9    60  2020/12/10        98       124       269.0
# 10        10    60  2020/12/11       103       147       329.3
# 11        11    60  2020/12/12       100       120       250.7
# 12        12    60  2020/12/12       100       120       250.7
# 13        13    60  2020/12/13       106       128       345.3
# ...

# %%
# df["Pulse"] = df["Pulse"].str.replace('\'', '', regex=True)
# df["Pulse"] = df["Pulse"].str.replace('\'', '', regex=False)
# df = df.rename(columns={'Date': 'Pulse', 'Pulse': 'Date'})
# df = df.drop('Unnamed: 5', axis=1)
df.head(5)
# Out:
#    Duration  Pulse        Date  Maxpulse  Calories
# 0         0     60  2020/12/01       110       130
# 1         1     60  2020/12/02       117       145
# 2         2     60  2020/12/03       103       135
# 3         3     45  2020/12/04       109       175
# 4         4     45  2020/12/05       117       148

# %%
# new_df = df.dropna()
# new_df
# root_df = df

# dropna drops rows that have Nan on any column
# df = df.dropna()

# df = root_df

# FIlls data in NaN values
# df.fillna('xy',inplace=True)


# df

# %%
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# <ipython-input-58-5fd1a6c1321f> in <cell line: 0>()
#       5
#       6 # print("Path to dataset files:", path)
# ----> 7 video_game_df = sandip_bhalu.read_csv("/root/.cache/kagglehub/datasets/gregorut/videogamesales/versions/2")
#
# ...
